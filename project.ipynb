# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('shopify_sales.csv')

# %%
print(df.shape)
# Out:
# (60000, 17)

# %%
display(print(df.columns))
# Out:
# Index(['order_id', 'order_date', 'customer_id', 'product_id',
#        'product_category', 'product_price', 'discount_percent', 'quantity',
#        'customer_country', 'traffic_source', 'payment_method', 'shipping_cost',
#        'rating', 'is_returned', 'discounted_price', 'revenue', 'profit'],
#       dtype='object')
# None

# %%
df.sample()
# Out:
#        order_id  order_date  customer_id  product_id product_category  \
# 57327     57328  05-08-2023        14029        7737      Electronics
#
#        product_price  discount_percent  quantity customer_country  \
# 57327         220.38                20         4              UAE
#
#       traffic_source payment_method  shipping_cost  rating  is_returned  \
# 57327        Organic      Apple Pay          16.53     1.2            0
#
#        discounted_price  revenue  profit
# 57327             176.3    705.2  688.67

# %%
df.head()
# Out:
#    order_id  order_date  customer_id  product_id product_category  \
# 0         1  13-04-2023        14958        7824      Accessories
# 1         2  11-03-2024        26825        5557           Sports
# 2         3  10-05-2025        37450        2225      Electronics
# 3         4  28-09-2023        20691        7855         Footwear
# 4         5  17-04-2023        24631        7789           Sports
#
#    product_price  discount_percent  quantity customer_country traffic_source  \
# 0         143.39                40         1              USA       Paid Ads
# 1         746.49                15         4              UAE          Email
# 2         641.06                 5         5           Canada       Paid Ads
# 3         512.39                 0         3              UAE         Direct
# 4         415.89                25         3              UAE   Social Media
#
#   payment_method  shipping_cost  rating  is_returned  discounted_price  \
# 0    Credit Card          21.08     2.0            0             86.03
# 1         PayPal           5.48     3.7            0            634.52
# 2      Apple Pay          11.27     3.2            0            609.01
# 3      Apple Pay          19.22     1.1            0            512.39
# 4     Debit Card          24.94     4.1            0            311.92
#
#    revenue   profit
# 0    86.03    64.95
# 1  2538.08  2532.60
# 2  3045.05  3033.78
# 3  1537.17  1517.95
# 4   935.76   910.82

# %%
df.tail()
# Out:
#        order_id  order_date  customer_id  product_id product_category  \
# 59995     59996  15-04-2025        11769        6227           Beauty
# 59996     59997  15-09-2024        49939        5122          Fashion
# 59997     59998  13-11-2024        41177        1077         Footwear
# 59998     59999  10-09-2023        18973        7151           Beauty
# 59999     60000  13-06-2025        42792        3304           Beauty
#
#        product_price  discount_percent  quantity customer_country  \
# 59995         434.55                 5         4            India
# 59996         397.02                 5         3              UAE
# 59997         390.80                 0         4              UAE
# 59998         365.99                40         3               UK
# 59999         565.95                15         4          Germany
#
#       traffic_source    payment_method  shipping_cost  rating  is_returned  \
# 59995         Direct            PayPal           5.12     3.9            0
# 59996          Email         Apple Pay           9.91     3.6            0
# 59997        Organic        Debit Card          16.61     4.1            0
# 59998       Paid Ads  Cash on Delivery           9.44     2.2            0
# 59999         Direct            PayPal           7.64     1.6            0
#
#        discounted_price  revenue   profit
# 59995            412.82  1651.28  1646.16
# 59996            377.17  1131.51  1121.60
# 59997            390.80  1563.20  1546.59
# 59998            219.59   658.77   649.33
# 59999            481.06  1924.24  1916.60

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          60000 non-null  int64
#  1   order_date        60000 non-null  object
#  2   customer_id       60000 non-null  int64
#  3   product_id        60000 non-null  int64
#  4   product_category  60000 non-null  object
#  5   product_price     60000 non-null  float64
#  6   discount_percent  60000 non-null  int64
#  7   quantity          60000 non-null  int64
#  8   customer_country  60000 non-null  object
#  9   traffic_source    60000 non-null  object
#  10  payment_method    60000 non-null  object
#  11  shipping_cost     60000 non-null  float64
#  12  rating            60000 non-null  float64
#  13  is_returned       60000 non-null  int64
#  14  discounted_price  60000 non-null  float64
#  15  revenue           60000 non-null  float64
#  16  profit            60000 non-null  float64
# dtypes: float64(6), int64(6), object(5)
# memory usage: 7.8+ MB
# None

# %%
display(df.describe(include='all'))
# Out:
#             order_id  order_date   customer_id    product_id product_category  \
# count   60000.000000       60000  60000.000000  60000.000000            60000
# unique           NaN         900           NaN           NaN                7
# top              NaN  18-10-2024           NaN           NaN      Electronics
# freq             NaN          92           NaN           NaN             8624
# mean    30000.500000         NaN  30035.075600   4504.738650              NaN
# std     17320.652413         NaN  11540.753215   2018.287018              NaN
# min         1.000000         NaN  10000.000000   1000.000000              NaN
# 25%     15000.750000         NaN  20037.750000   2751.750000              NaN
# 50%     30000.500000         NaN  30079.000000   4503.500000              NaN
# 75%     45000.250000         NaN  40036.250000   6257.000000              NaN
# max     60000.000000         NaN  49999.000000   7999.000000              NaN
#
#         product_price  discount_percent      quantity customer_country  \
# count    60000.000000      60000.000000  60000.000000            60000
# unique            NaN               NaN           NaN                7
# top               NaN               NaN           NaN        Australia
# freq              NaN               NaN           NaN             8714
# mean       403.427068         18.151500      3.009567              NaN
# std        230.045257         12.527663      1.414794              NaN
# min          5.010000          0.000000      1.000000              NaN
# 25%        203.160000          5.000000      2.000000              NaN
# 50%        403.855000         20.000000      3.000000              NaN
# 75%        603.135000         30.000000      4.000000              NaN
# max        799.990000         40.000000      5.000000              NaN
#
#        traffic_source payment_method  shipping_cost        rating  \
# count           60000          60000   60000.000000  60000.000000
# unique              5              5            NaN           NaN
# top           Organic      Apple Pay            NaN           NaN
# freq            12075          12116            NaN           NaN
# mean              NaN            NaN      13.521758      3.002440
# std               NaN            NaN       6.627934      1.152265
# min               NaN            NaN       2.000000      1.000000
# 25%               NaN            NaN       7.760000      2.000000
# 50%               NaN            NaN      13.580000      3.000000
# 75%               NaN            NaN      19.230000      4.000000
# max               NaN            NaN      25.000000      5.000000
#
#          is_returned  discounted_price       revenue        profit
# count   60000.000000      60000.000000  60000.000000  60000.000000
# unique           NaN               NaN           NaN           NaN
# top              NaN               NaN           NaN           NaN
# freq             NaN               NaN           NaN           NaN
# mean        0.148117        330.220212    994.098926    980.577168
# std         0.355219        197.114822    806.445785    806.508355
# min         0.000000          3.080000      3.080000    -20.490000
# 25%         0.000000        161.957500    355.620000    341.925000
# 50%         0.000000        322.560000    760.470000    747.275000
# 75%         0.000000        482.242500   1462.450000   1449.807500
# max         1.000000        799.900000   3999.500000   3989.950000

# %%
display(df.describe())
# Out:
#            order_id   customer_id    product_id  product_price  \
# count  60000.000000  60000.000000  60000.000000   60000.000000
# mean   30000.500000  30035.075600   4504.738650     403.427068
# std    17320.652413  11540.753215   2018.287018     230.045257
# min        1.000000  10000.000000   1000.000000       5.010000
# 25%    15000.750000  20037.750000   2751.750000     203.160000
# 50%    30000.500000  30079.000000   4503.500000     403.855000
# 75%    45000.250000  40036.250000   6257.000000     603.135000
# max    60000.000000  49999.000000   7999.000000     799.990000
#
#        discount_percent      quantity  shipping_cost        rating  \
# count      60000.000000  60000.000000   60000.000000  60000.000000
# mean          18.151500      3.009567      13.521758      3.002440
# std           12.527663      1.414794       6.627934      1.152265
# min            0.000000      1.000000       2.000000      1.000000
# 25%            5.000000      2.000000       7.760000      2.000000
# 50%           20.000000      3.000000      13.580000      3.000000
# 75%           30.000000      4.000000      19.230000      4.000000
# max           40.000000      5.000000      25.000000      5.000000
#
#         is_returned  discounted_price       revenue        profit
# count  60000.000000      60000.000000  60000.000000  60000.000000
# mean       0.148117        330.220212    994.098926    980.577168
# std        0.355219        197.114822    806.445785    806.508355
# min        0.000000          3.080000      3.080000    -20.490000
# 25%        0.000000        161.957500    355.620000    341.925000
# 50%        0.000000        322.560000    760.470000    747.275000
# 75%        0.000000        482.242500   1462.450000   1449.807500
# max        1.000000        799.900000   3999.500000   3989.950000

# %%
df.isnull().sum()
(df.isnull().sum() / len(df)) * 100
# Out:
# order_id            0.0
# order_date          0.0
# customer_id         0.0
# product_id          0.0
# product_category    0.0
# product_price       0.0
# discount_percent    0.0
# quantity            0.0
# customer_country    0.0
# traffic_source      0.0
# payment_method      0.0
# shipping_cost       0.0
# rating              0.0
# is_returned         0.0
# discounted_price    0.0
# revenue             0.0
# profit              0.0
# dtype: float64

# %%
print(df.duplicated().sum())
df = df.drop_duplicates()
# Out:
# 0

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
cat_cols = df.select_dtypes(include=['object']).columns
print('Numerical Columns:', list(num_cols))
print('Categorical Columns:', list(cat_cols))
# Out:
# Numerical Columns: ['order_id', 'customer_id', 'product_id', 'product_price', 'discount_percent', 'quantity', 'shipping_cost', 'rating', 'is_returned', 'discounted_price', 'revenue', 'profit']
# Categorical Columns: ['order_date', 'product_category', 'customer_country', 'traffic_source', 'payment_method']

# %%
df['payment_method'].value_counts().plot(kind='bar')
plt.show()

# %%
sns.countplot(x='product_category', data=df)
plt.show()

# %%
df['product_category'].value_counts().plot(kind='bar')
plt.show()

# %%
plt.scatter(df['revenue'], df['profit'])
plt.show()

# %%
df.groupby('product_category')['revenue'].mean().plot(kind='bar')
plt.show()

# %%
df['customer_country'].value_counts().plot(kind='bar')
plt.show()

# %%
df.groupby('product_category')['profit'].sum().sort_values(ascending=False)
# Out:
# product_category
# Electronics    8601068.01
# Accessories    8492938.90
# Beauty         8429076.60
# Home Decor     8428664.14
# Fashion        8327844.15
# Sports         8319929.75
# Footwear       8235108.55
# Name: profit, dtype: float64

# %%
df.groupby('discount_percent')['revenue'].mean()
# Out:
# discount_percent
# 0     1201.895354
# 5     1164.717318
# 10    1088.680441
# 15    1041.791812
# 20     973.394752
# 25     905.904865
# 30     857.993470
# 40     721.339733
# Name: revenue, dtype: float64

# %%
df.groupby('traffic_source')['revenue'].sum()
# Out:
# traffic_source
# Direct          11953141.33
# Email           11823943.67
# Organic         11907664.90
# Paid Ads        11939378.20
# Social Media    12021807.48
# Name: revenue, dtype: float64

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()
